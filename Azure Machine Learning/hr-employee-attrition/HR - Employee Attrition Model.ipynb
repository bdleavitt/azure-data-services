# %% [markdown]
# ## Predicting Employee Attrition using Azure ML Services
# A classification exercise predicting how likely an employee is to leave the company. Based on the [IBM employee data set](https://www.ibm.com/communities/analytics/watson-analytics-blog/hr-employee-attrition/)

# %% [markdown]
# ### Configure Azure ML Workspace

# %%
# %matplotlib inline

import azureml.core
import pandas as pd
import numpy as np
from azureml.core.workspace import Workspace
import logging
import os

# %%
ws = Workspace.from_config()
# choose a name for the run history container in the workspace
experiment_name = 'hr-employee-attrition'
# project folder
project_folder = './hr-employee-attrition'

output = {}
output['SDK version'] = azureml.core.VERSION
output['Subscription ID'] = ws.subscription_id
output['Workspace'] = ws.name
output['Resource Group'] = ws.resource_group
output['Location'] = ws.location
output['Project Directory'] = project_folder
pd.set_option('display.max_colwidth', -1)
pd.DataFrame(data=output, index=['']).T
# Out:
# Found the config file in: C:\GitRepos\azure-data-services\wip\hr-employee-attrition\config.json
#
# SDK version        1.0.17
# Subscription ID    eb489f58-b7f7-4001-a82b-bc18cac70b3b
# Workspace          bdl-aml-demo
# Resource Group     bdl-cognitive-services
# Location           eastus2
# Project Directory  ./hr-employee-attrition

# %% [markdown]
# ### Load Data

# %%
import azureml.dataprep as dprep
dflow = dprep.auto_read_file(path="WA_Fn-UseC_-HR-Employee-Attrition.csv")
dflow.head(5)
# Out:
#     Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0  41.0  True       Travel_Rarely      1102.0     Sales
# 1  49.0  False      Travel_Frequently  279.0      Research & Development
# 2  37.0  True       Travel_Rarely      1373.0     Research & Development
# 3  33.0  False      Travel_Frequently  1392.0     Research & Development
# 4  27.0  False      Travel_Rarely      591.0      Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0  1.0               2.0        Life Sciences  1.0            1.0
# 1  8.0               1.0        Life Sciences  1.0            2.0
# 2  2.0               2.0        Other          1.0            4.0
# 3  3.0               4.0        Life Sciences  1.0            5.0
# 4  2.0               1.0        Medical        1.0            7.0
#
#            ...           RelationshipSatisfaction StandardHours  \
# 0          ...           1.0                       80.0
# 1          ...           4.0                       80.0
# 2          ...           2.0                       80.0
# 3          ...           3.0                       80.0
# 4          ...           4.0                       80.0
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0  0.0               8.0                0.0                    1.0
# 1  1.0               10.0               3.0                    3.0
# 2  0.0               7.0                3.0                    3.0
# 3  0.0               8.0                3.0                    3.0
# 4  1.0               6.0                3.0                    3.0
#
#    YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0  6.0             4.0                0.0
# 1  10.0            7.0                1.0
# 2  0.0             0.0                0.0
# 3  8.0             7.0                3.0
# 4  2.0             2.0                2.0
#
#    YearsWithCurrManager
# 0  5.0
# 1  7.0
# 2  0.0
# 3  0.0
# 4  2.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Clean & Engineer Data

# %%
dflow.get_profile()
# Out:
# ColumnProfile:
#     column_name: Age
#     type: FieldType.DECIMAL
#
#     min: 18.0
#     max: 60.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 18.0
#            1%: 26.0
#            5%: 26.0
#           25%: 30.0
#           50%: 35.74579831932773
#           75%: 43.0
#           95%: 54.11688311688311
#           99%: 58.54666666666666
#         99.9%: 60.0
#
#     mean: 36.92380952380955
#     std: 9.135373489136729
#     variance: 83.45504878602216
#     skewness: 0.4124432429370963
#     kurtosis: -0.4103775546394748
#
# ColumnProfile:
#     column_name: Attrition
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: BusinessTravel
#     type: FieldType.STRING
#
#     min: Non-Travel
#     max: Travel_Rarely
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: DailyRate
#     type: FieldType.DECIMAL
#
#     min: 102.0
#     max: 1499.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 102.97
#            1%: 243.014652014652
#            5%: 239.14285714285714
#           25%: 465.28311688311686
#           50%: 801.0447957839262
#           75%: 1158.78
#           95%: 1424.03125
#           99%: 1485.32
#         99.9%: 1498.03
#
#     mean: 802.4857142857131
#     std: 403.509099943528
#     variance: 162819.59373723608
#     skewness: -0.0035113908571632723
#     kurtosis: -1.206253891336086
#
# ColumnProfile:
#     column_name: Department
#     type: FieldType.STRING
#
#     min: Human Resources
#     max: Sales
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: DistanceFromHome
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 29.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 1.0
#            5%: 1.0
#           25%: 2.0
#           50%: 7.0
#           75%: 14.014285714285714
#           95%: 26.0
#           99%: 29.0
#         99.9%: 29.0
#
#     mean: 9.19251700680272
#     std: 8.10686443566608
#     variance: 65.72125097826752
#     skewness: 0.9561635395853479
#     kurtosis: -0.2319181954598477
#
# ColumnProfile:
#     column_name: Education
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 5.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 1.0
#            5%: 1.0
#           25%: 2.0
#           50%: 3.0
#           75%: 4.0
#           95%: 4.0
#           99%: 5.0
#         99.9%: 5.0
#
#     mean: 2.9129251700680276
#     std: 1.0241649445978718
#     variance: 1.0489138337431616
#     skewness: -0.2890901641983763
#     kurtosis: -0.5646107220060537
#
# ColumnProfile:
#     column_name: EducationField
#     type: FieldType.STRING
#
#     min: Human Resources
#     max: Technical Degree
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: EmployeeCount
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 1.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 1.0
#            5%: 1.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.9999999999999999
#     std: 0.0
#     variance: 0.0
#     skewness: nan
#     kurtosis: nan
#
# ColumnProfile:
#     column_name: EmployeeNumber
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 2068.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.97
#            1%: 198.27777777777774
#            5%: 193.5
#           25%: 490.06666666666666
#           50%: 1021.1632653061225
#           75%: 1556.595
#           95%: 1967.6666666666665
#           99%: 2047.44
#         99.9%: 2065.09
#
#     mean: 1024.865306122449
#     std: 602.0243348474752
#     variance: 362433.29974854493
#     skewness: 0.016540210390272262
#     kurtosis: -1.225517978818204
#
# ColumnProfile:
#     column_name: EnvironmentSatisfaction
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 4.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 1.0
#            5%: 1.0
#           25%: 2.0
#           50%: 3.0
#           75%: 4.0
#           95%: 4.0
#           99%: 4.0
#         99.9%: 4.0
#
#     mean: 2.7217687074829935
#     std: 1.0930822146350003
#     variance: 1.194828727951357
#     skewness: -0.3209983077950814
#     kurtosis: -1.2049577960323685
#
# ColumnProfile:
#     column_name: Gender
#     type: FieldType.STRING
#
#     min: Female
#     max: Male
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: HourlyRate
#     type: FieldType.DECIMAL
#
#     min: 30.0
#     max: 100.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 30.0
#            1%: 37.8015873015873
#            5%: 37.44444444444444
#           25%: 48.1875
#           50%: 65.91614906832298
#           75%: 83.52272727272727
#           95%: 97.02083333333333
#           99%: 100.0
#         99.9%: 100.0
#
#     mean: 65.89115646258502
#     std: 20.329427593996176
#     variance: 413.28562629953313
#     skewness: -0.03224504208533302
#     kurtosis: -1.1988648322355862
#
# ColumnProfile:
#     column_name: JobInvolvement
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 4.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 2.0
#            5%: 2.0
#           25%: 2.0
#           50%: 3.0
#           75%: 3.0
#           95%: 4.0
#           99%: 4.0
#         99.9%: 4.0
#
#     mean: 2.7299319727891174
#     std: 0.7115611429632297
#     variance: 0.5063192601751378
#     skewness: -0.4974026429735557
#     kurtosis: 0.261556996830659
#
# ColumnProfile:
#     column_name: JobLevel
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 5.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 1.0
#            5%: 1.0
#           25%: 1.0
#           50%: 2.0
#           75%: 3.0
#           95%: 4.0
#           99%: 5.0
#         99.9%: 5.0
#
#     mean: 2.063945578231286
#     std: 1.1069398989351202
#     variance: 1.2253159398544942
#     skewness: 1.0233095763225304
#     kurtosis: 0.38910109850252983
#
# ColumnProfile:
#     column_name: JobRole
#     type: FieldType.STRING
#
#     min: Healthcare Representative
#     max: Sales Representative
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: JobSatisfaction
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 4.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 1.0
#            5%: 1.0
#           25%: 2.0
#           50%: 3.0
#           75%: 4.0
#           95%: 4.0
#           99%: 4.0
#         99.9%: 4.0
#
#     mean: 2.7285714285714326
#     std: 1.1028461230547213
#     variance: 1.2162695711368294
#     skewness: -0.32899946387270157
#     kurtosis: -1.2245363300361767
#
# ColumnProfile:
#     column_name: MaritalStatus
#     type: FieldType.STRING
#
#     min: Divorced
#     max: Single
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: MonthlyIncome
#     type: FieldType.DECIMAL
#
#     min: 1009.0
#     max: 19999.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1049.74
#            1%: 2315.527777777778
#            5%: 2306.6666666666665
#           25%: 2913.225
#           50%: 4921.283596837944
#           75%: 8351.96923076923
#           95%: 17805.104761904764
#           99%: 19629.68
#         99.9%: 19973.78
#
#     mean: 6502.931292517012
#     std: 4707.956783097992
#     variance: 22164857.071518395
#     skewness: 1.367022404412976
#     kurtosis: 0.9923006802865464
#
# ColumnProfile:
#     column_name: MonthlyRate
#     type: FieldType.DECIMAL
#
#     min: 2094.0
#     max: 26999.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 2096.91
#            1%: 4573.710622710622
#            5%: 4494.428571428572
#           25%: 8079.866666666667
#           50%: 14242.168972332016
#           75%: 20477.524242424242
#           95%: 25453.666666666668
#           99%: 26704.466666666664
#         99.9%: 26997.059999999998
#
#     mean: 14313.103401360513
#     std: 7117.786044059972
#     variance: 50662878.16901489
#     skewness: 0.018539911191986842
#     kurtosis: -1.2173342602792128
#
# ColumnProfile:
#     column_name: NumCompaniesWorked
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 9.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 2.0
#           75%: 4.0
#           95%: 8.0
#           99%: 9.0
#         99.9%: 9.0
#
#     mean: 2.6931972789115646
#     std: 2.4980090060707463
#     variance: 6.240048994410558
#     skewness: 1.024377223004557
#     kurtosis: 0.002011709787185456
#
# ColumnProfile:
#     column_name: Over18
#     type: FieldType.BOOLEAN
#
#     min: True
#     max: True
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: OverTime
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: PercentSalaryHike
#     type: FieldType.DECIMAL
#
#     min: 11.0
#     max: 25.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 11.0
#            1%: 11.0
#            5%: 11.0
#           25%: 12.0
#           50%: 14.0
#           75%: 18.0
#           95%: 22.0
#           99%: 25.0
#         99.9%: 25.0
#
#     mean: 15.209523809523821
#     std: 3.6599377165396385
#     variance: 13.395144088949385
#     skewness: 0.8194529641863803
#     kurtosis: -0.30732285834105477
#
# ColumnProfile:
#     column_name: PerformanceRating
#     type: FieldType.DECIMAL
#
#     min: 3.0
#     max: 4.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 3.0
#            1%: 3.0
#            5%: 3.0
#           25%: 3.0
#           50%: 3.0
#           75%: 3.0
#           95%: 4.0
#           99%: 4.0
#         99.9%: 4.0
#
#     mean: 3.1537414965986454
#     std: 0.36082352460434397
#     variance: 0.1301936159079016
#     skewness: 1.9179622713262574
#     kurtosis: 1.6797233311593613
#
# ColumnProfile:
#     column_name: RelationshipSatisfaction
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 4.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 1.0
#            5%: 1.0
#           25%: 2.0
#           50%: 3.0
#           75%: 4.0
#           95%: 4.0
#           99%: 4.0
#         99.9%: 4.0
#
#     mean: 2.7122448979591858
#     std: 1.0812088864403517
#     variance: 1.1690126561175855
#     skewness: -0.30220983001071117
#     kurtosis: -1.1873354256019806
#
# ColumnProfile:
#     column_name: StandardHours
#     type: FieldType.DECIMAL
#
#     min: 80.0
#     max: 80.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 80.0
#            1%: 80.0
#            5%: 80.0
#           25%: 80.0
#           50%: 80.0
#           75%: 80.0
#           95%: 80.0
#           99%: 80.0
#         99.9%: 80.0
#
#     mean: 80.0
#     std: 0.0
#     variance: 0.0
#     skewness: nan
#     kurtosis: nan
#
# ColumnProfile:
#     column_name: StockOptionLevel
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 3.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.0
#           75%: 1.0
#           95%: 3.0
#           99%: 3.0
#         99.9%: 3.0
#
#     mean: 0.7938775510204085
#     std: 0.8520766679308381
#     variance: 0.7260346480321198
#     skewness: 0.9670037027536514
#     kurtosis: 0.35474745974956123
#
# ColumnProfile:
#     column_name: TotalWorkingYears
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 40.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 3.0
#            5%: 3.0
#           25%: 6.0
#           50%: 9.930672268907562
#           75%: 15.054545454545455
#           95%: 28.0
#           99%: 35.07999999999999
#         99.9%: 40.0
#
#     mean: 11.279591836734703
#     std: 7.780781675514995
#     variance: 60.54056348202993
#     skewness: 1.1148929442436488
#     kurtosis: 0.9057509119846063
#
# ColumnProfile:
#     column_name: TrainingTimesLastYear
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 6.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 2.0
#            5%: 2.0
#           25%: 2.0
#           50%: 3.0
#           75%: 3.0
#           95%: 5.0
#           99%: 6.0
#         99.9%: 6.0
#
#     mean: 2.799319727891153
#     std: 1.2892706207958466
#     variance: 1.6622187336473075
#     skewness: 0.551995858153519
#     kurtosis: 0.48448644138489705
#
# ColumnProfile:
#     column_name: WorkLifeBalance
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 4.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 2.0
#            5%: 2.0
#           25%: 2.0
#           50%: 3.0
#           75%: 3.0
#           95%: 4.0
#           99%: 4.0
#         99.9%: 4.0
#
#     mean: 2.7612244897959215
#     std: 0.7064758297141507
#     variance: 0.49910809797029765
#     skewness: -0.5513532996248051
#     kurtosis: 0.4093130005893242
#
# ColumnProfile:
#     column_name: YearsAtCompany
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 40.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 3.0
#           50%: 5.0
#           75%: 9.391826923076923
#           95%: 20.0
#           99%: 31.07999999999999
#         99.9%: 37.08999999999992
#
#     mean: 7.008163265306127
#     std: 6.126525152403571
#     variance: 37.53431044303359
#     skewness: 1.7609300069662353
#     kurtosis: 3.908647435719451
#
# ColumnProfile:
#     column_name: YearsInCurrentRole
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 18.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 2.0
#           50%: 3.0
#           75%: 7.0
#           95%: 10.904761904761903
#           99%: 15.21666666666666
#         99.9%: 18.0
#
#     mean: 4.229251700680271
#     std: 3.623137034670627
#     variance: 13.127121972001866
#     skewness: 0.9154918356406663
#     kurtosis: 0.46699775982006075
#
# ColumnProfile:
#     column_name: YearsSinceLastPromotion
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 15.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.0
#           75%: 2.892857142857143
#           95%: 9.266666666666667
#           99%: 14.079999999999988
#         99.9%: 15.0
#
#     mean: 2.187755102040815
#     std: 3.2224302791379693
#     variance: 10.38405690390521
#     skewness: 1.9802422484982056
#     kurtosis: 3.5873464203516097
#
# ColumnProfile:
#     column_name: YearsWithCurrManager
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 17.0
#     count: 1470.0
#     missing_count: 0.0
#     not_missing_count: 1470.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 2.0
#           50%: 3.0
#           75%: 7.0
#           95%: 10.461538461538462
#           99%: 14.239999999999986
#         99.9%: 17.0
#
#     mean: 4.123129251700682
#     std: 3.5681361205404363
#     variance: 12.731595374705353
#     skewness: 0.8317508429924969
#     kurtosis: 0.1620913904945076

# %% [markdown]
# ### Prep and Split Data

# %%
## Keep all features except the predicted status ("Attrition")
predictors_df = dflow.drop_columns(["Attrition"]).to_pandas_dataframe()
target_df = dflow.keep_columns(["Attrition"]).to_pandas_dataframe()

# %%
## split into test/train sets
from sklearn.model_selection import train_test_split

predictors_df = predictors_df.to_pandas_dataframe()
target_df = target_df.to_pandas_dataframe()

predictors_train, predictors_test, target_train, target_test = train_test_split(predictors_df, target_df, test_size=0.2, random_state=223)

# %%
target_train.describe()
# Out:
#        Attrition
# count   1176
# unique  2
# top     False
# freq    993

# %% [markdown]
# ### Automated Training / Testing 50 Different Models

# %%
from azureml.train.automl import AutoMLConfig

automl_classifier_config = AutoMLConfig(
    task="classification",
    primary_metric='AUC_weighted',
    
    iteration_timeout_minutes = 15,
    iterations = 50,
    X=predictors_train,
    y=target_train.values.flatten(),
    n_cross_validations = 5,
    preprocess=True
)

# %%
from azureml.core.experiment import Experiment
experiment=Experiment(ws, experiment_name)
local_run = experiment.submit(automl_classifier_config, show_output=True)
# Out:
# Running on local machine
# Parent Run ID: AutoML_4563a6c2-b74c-40a5-be3f-c2926aa07fc3
# ********************************************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# SAMPLING %: Percent of the training data to sample.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# ********************************************************************************************************************
#
#  ITERATION   PIPELINE                                       SAMPLING %  DURATION      METRIC      BEST
#          0   SparseNormalizer LightGBM                      100.0000    0:00:16       0.7702    0.7702
#          1   SparseNormalizer LightGBM                      100.0000    0:00:16       0.8135    0.8135
#          2   StandardScalerWrapper LightGBM                 100.0000    0:00:12       0.8177    0.8177
#          3   StandardScalerWrapper LightGBM                 100.0000    0:00:11       0.7951    0.8177
#          4   StandardScalerWrapper LightGBM                 100.0000    0:00:11       0.7917    0.8177
#          5   SparseNormalizer LightGBM                      100.0000    0:00:14       0.8003    0.8177
#          6   MaxAbsScaler LightGBM                          100.0000    0:00:11       0.8172    0.8177
#          7   StandardScalerWrapper LightGBM                 100.0000    0:00:12       0.7977    0.8177
#          8   MaxAbsScaler LightGBM                          100.0000    0:00:15       0.8410    0.8410
#          9   MaxAbsScaler DecisionTree                      100.0000    0:00:13       0.6924    0.8410
#         10   MaxAbsScaler LogisticRegression                100.0000    0:00:10       0.8366    0.8410
#         11   StandardScalerWrapper LightGBM                 100.0000    0:00:11       0.8238    0.8410
#         12   StandardScalerWrapper LogisticRegression       100.0000    0:00:14       0.8354    0.8410
#         13   MaxAbsScaler LightGBM                          100.0000    0:00:15       0.8119    0.8410
#         14   MaxAbsScaler LightGBM                          100.0000    0:00:15       0.7650    0.8410
#         15   SparseNormalizer LightGBM                      100.0000    0:00:22       0.8052    0.8410
#         16   StandardScalerWrapper LightGBM                 100.0000    0:00:15       0.8123    0.8410
#         17   SparseNormalizer LightGBM                      100.0000    0:00:12       0.7912    0.8410
#         18   MaxAbsScaler ExtremeRandomTrees                100.0000    0:00:18       0.7990    0.8410
#         19   StandardScalerWrapper LightGBM                 100.0000    0:00:33       0.7854    0.8410
#         20   StandardScalerWrapper LogisticRegression       100.0000    0:00:28       0.8406    0.8410
#         21   MaxAbsScaler LightGBM                          100.0000    0:00:18       0.8085    0.8410
#         22   StandardScalerWrapper LinearSVM                100.0000    0:00:19       0.8298    0.8410
#         23   StandardScalerWrapper LogisticRegression       100.0000    0:00:19       0.7838    0.8410
#         24   TruncatedSVDWrapper LogisticRegression         100.0000    0:00:35       0.8294    0.8410
#         25   MaxAbsScaler GradientBoosting                  100.0000    0:00:16       0.7385    0.8410
#         26   StandardScalerWrapper LogisticRegression       100.0000    0:00:19       0.8407    0.8410
#         27   StandardScalerWrapper LinearSVM                100.0000    0:00:18       0.8046    0.8410
#         28   StandardScalerWrapper LogisticRegression       100.0000    0:00:13       0.6155    0.8410
#         29   MaxAbsScaler LightGBM                          100.0000    0:00:21       0.8093    0.8410
#         30   StandardScalerWrapper LightGBM                 100.0000    0:00:15       0.8201    0.8410
#         31   MaxAbsScaler LogisticRegression                100.0000    0:00:13       0.8361    0.8410
#         32   MaxAbsScaler LinearSVM                         100.0000    0:00:15       0.8357    0.8410
#         33   StandardScalerWrapper LinearSVM                100.0000    0:00:13       0.8347    0.8410
#         34   MaxAbsScaler ExtremeRandomTrees                100.0000    0:00:17       0.7670    0.8410
#         35   StandardScalerWrapper LightGBM                 100.0000    0:00:16       0.8099    0.8410
#         36   MaxAbsScaler ExtremeRandomTrees                100.0000    0:00:26       0.7396    0.8410
#         37   MaxAbsScaler LinearSVM                         100.0000    0:00:16       0.8345    0.8410
#         38   StandardScalerWrapper GradientBoosting         100.0000    0:00:22       0.8089    0.8410
#         39   StandardScalerWrapper LogisticRegression       100.0000    0:00:19       0.8413    0.8413
#         40   StandardScalerWrapper LogisticRegression       100.0000    0:00:19       0.8383    0.8413
#         41   SparseNormalizer LogisticRegression            100.0000    0:00:16       0.6285    0.8413
#         42   TruncatedSVDWrapper LogisticRegression         100.0000    0:00:27       0.8363    0.8413
#         43   StandardScalerWrapper LightGBM                 100.0000    0:00:15       0.8374    0.8413
#         44   StandardScalerWrapper LogisticRegression       100.0000    0:00:22       0.8354    0.8413
#         45   MaxAbsScaler LightGBM                          100.0000    0:00:23       0.8272    0.8413
#         46   StandardScalerWrapper LightGBM                 100.0000    0:00:20       0.8333    0.8413
#         47   MaxAbsScaler RandomForest                      100.0000    0:00:19       0.7928    0.8413
#         48   MaxAbsScaler RandomForest                      100.0000    0:00:28       0.7751    0.8413
#         49   Ensemble                                       100.0000    0:01:19       0.8564    0.8564

# %% [markdown]
# ### Evaluate Model Results

# %%
best_run, fitted_model = local_run.get_output()
print(best_run)
print(fitted_model)
# Out:
# Run(Experiment: hr-employee-attrition,
# Id: AutoML_4563a6c2-b74c-40a5-be3f-c2926aa07fc3_49,
# Type: None,
# Status: Completed)
# Pipeline(memory=None,
#      steps=[('datatransformer', DataTransformer(logger=None, task=None)), ('prefittedsoftvotingclassifier', PreFittedSoftVotingClassifier(classification_labels=None,
#                estimators=[('LogisticRegression', Pipeline(memory=None,
#      steps=[('maxabsscaler', MaxAbsScaler(copy=True)), ('logisticre....06666666666666667, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667, 0.2, 0.2, 0.2]))])
# Y_transformer(['LabelEncoder', LabelEncoder()])

# %%
type(local_run)
type(fitted_model)
# Out:
# automl.client.core.common.model_wrappers.PipelineWithYTransformations

# %%
predictions = fitted_model.predict(predictors_df)
prediction_probabilities = fitted_model.predict_proba(predictors_df)

full_results_df = predictors_df
full_results_df['Attrition - Actual'] = target_df
full_results_df['Attrition - Predicted'] = predictions
full_results_df.head(5)
# Out:
#     Age     BusinessTravel  DailyRate              Department  \
# 0 41.00  Travel_Rarely     1102.00     Sales
# 1 49.00  Travel_Frequently 279.00      Research & Development
# 2 37.00  Travel_Rarely     1373.00     Research & Development
# 3 33.00  Travel_Frequently 1392.00     Research & Development
# 4 27.00  Travel_Rarely     591.00      Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0 1.00              2.00        Life Sciences 1.00           1.00
# 1 8.00              1.00        Life Sciences 1.00           2.00
# 2 2.00              2.00        Other         1.00           4.00
# 3 3.00              4.00        Life Sciences 1.00           5.00
# 4 2.00              1.00        Medical       1.00           7.00
#
#    EnvironmentSatisfaction         ...         StockOptionLevel  \
# 0 2.00                             ...         0.00
# 1 3.00                             ...         1.00
# 2 4.00                             ...         0.00
# 3 4.00                             ...         0.00
# 4 1.00                             ...         1.00
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 0 8.00               0.00                   1.00             6.00
# 1 10.00              3.00                   3.00             10.00
# 2 7.00               3.00                   3.00             0.00
# 3 8.00               3.00                   3.00             8.00
# 4 6.00               3.00                   3.00             2.00
#
#    YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager  \
# 0 4.00                0.00                    5.00
# 1 7.00                1.00                    7.00
# 2 0.00                0.00                    0.00
# 3 7.00                3.00                    0.00
# 4 2.00                2.00                    2.00
#
#    Attrition - Predicted  Attrition - Actual
# 0  True                   True
# 1  False                  False
# 2  True                   True
# 3  False                  False
# 4  False                  False
#
# [5 rows x 36 columns]

# %%
full_results_df.to_csv("employee_attrition_with_prediction.csv")

# %%
type(predictions)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Publish as Webservice
